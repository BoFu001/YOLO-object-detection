# %% [markdown]
# ## INM705 Deep Learning for Image Analysis
# #### Object detection with YOLO
# #### Author: Bo Fu, Yehoshua Perez Condori

# %%
# YOLO parameters
S = 7
B = 2
C = 20

# training parameters
BATCH_SIZE = 16
EPOCHS     = 60
LR         = 1e-3

# %%
from modules.Dataset import get_dataloaders


train_loader, val_loader, test_loader = get_dataloaders(BATCH_SIZE, S, B, C)

# get one batch
imgs, targets = next(iter(train_loader))

print("imgs shape:   ", imgs.shape)     # (16, 3, 448, 448)
print("targets shape:", targets.shape)  # (16, 7, 7, 30)
# Out:
# Train set: 5717 images
# Val set:   5823 images
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 4
#       1 from modules.Dataset import get_dataloaders
# ----> 4 train_loader, val_loader, test_loader = get_dataloaders(BATCH_SIZE, S, B, C)
#       6 # get one batch
#       7 imgs, targets = next(iter(train_loader))
#
# ValueError: not enough values to unpack (expected 3, got 2)
